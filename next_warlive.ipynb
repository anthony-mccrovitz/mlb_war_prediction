# %%
import os 
import pandas as pd
import numpy as np
from pybaseball import batting_stats

# %%
START = 2004
END = 2024

# %%
batting = batting_stats(START, END, qual=200)

# %%
batting.to_csv("batting.csv")

# %%
batting = batting.groupby("IDfg", group_keys=False).filter(lambda x: x.shape[0] > 1)

# %%
# This data frame is all of the batting data for players between 2004-2024 who have had at least 200 plate appeareances
batting
# Out:
#        IDfg  Season                 Name   Team  Age    G   AB   PA    H   1B  \
# 0      1109    2004          Barry Bonds    SFG   39  147  373  617  135   60
# 4     15640    2022          Aaron Judge    NYY   30  157  570  696  177   87
# 10    13611    2018         Mookie Betts    BOS   25  136  520  614  180   96
# 70    10155    2013           Mike Trout    LAA   21  157  589  716  190  115
# 157   10155    2012           Mike Trout    LAA   20  139  559  639  182  117
# ...     ...     ...                  ...    ...  ...  ...  ...  ...  ...  ...
# 6452   8585    2009  Yuniesky Betancourt  - - -   27  134  470  508  115   83
# 7006   9272    2018          Chris Davis    BAL   32  128  470  522   79   51
# 6474     45    2012          Rod Barajas    PIT   36  104  321  361   66   44
# 6620    319    2011            Adam Dunn    CHW   31  122  415  496   66   39
# 903    2113    2008          Ryan Doumit    PIT   27  116  431  465  137   88
#
#       ...  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xBA  xSLG  xwOBA  \
# 0     ...    NaN      NaN       NaN       0  0.124  0.164  NaN   NaN    NaN
# 4     ...  118.4    246.0     0.609     404  0.169  0.287  NaN   NaN    NaN
# 10    ...  110.6    217.0     0.500     434  0.220  0.270  NaN   NaN    NaN
# 70    ...    NaN      0.0       NaN       0  0.200  0.266  NaN   NaN    NaN
# 157   ...    NaN      0.0       NaN       0  0.221  0.293  NaN   NaN    NaN
# ...   ...    ...      ...       ...     ...    ...    ...  ...   ...    ...
# 6452  ...    NaN      0.0       NaN       0  0.181  0.232  NaN   NaN    NaN
# 7006  ...  111.8    113.0     0.401     282  0.174  0.316  NaN   NaN    NaN
# 6474  ...    NaN      0.0       NaN       0  0.147  0.258  NaN   NaN    NaN
# 6620  ...    NaN      0.0       NaN       0  0.169  0.295  NaN   NaN    NaN
# 903   ...    NaN      0.0       NaN       0  0.144  0.231  NaN   NaN    NaN
#
#       L-WAR
# 0      11.9
# 4      11.6
# 10     10.4
# 70     10.1
# 157    10.1
# ...     ...
# 6452   -2.4
# 7006   -2.6
# 6474   -2.6
# 6620   -2.9
# 903    -3.1
#
# [6744 rows x 320 columns]

# %%
def next_season(player):
    player = player.sort_values("Season")
    player["NEXT_WAR"] = player["WAR"].shift(-1)
    return player

batting = batting.groupby("IDfg", group_keys=False).apply(next_season)
# Out:
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/3388785127.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   batting = batting.groupby("IDfg", group_keys=False).apply(next_season)

# %%
batting[["Name", "Season", "WAR", "NEXT_WAR"]]
# Out:
#                   Name  Season  WAR  NEXT_WAR
# 5484   Alfredo Amezaga    2006  1.1       2.0
# 4909   Alfredo Amezaga    2007  2.0       1.2
# 5157   Alfredo Amezaga    2008  1.2       NaN
# 2478   Garret Anderson    2004  0.8      -0.2
# 4069   Garret Anderson    2005 -0.2       0.1
# ...                ...     ...  ...       ...
# 1215      Seiya Suzuki    2024  2.3       NaN
# 5081         Zach Neto    2023  1.1       2.2
# 3004         Zach Neto    2024  2.2       NaN
# 2421  Masataka Yoshida    2023  0.6       0.1
# 3785  Masataka Yoshida    2024  0.1       NaN
#
# [6744 rows x 4 columns]

# %%
null_count = batting.isnull().sum()

# %%
null_count
# Out:
# IDfg           0
# Season         0
# Name           0
# Team           0
# Age            0
#             ...
# xBA         6744
# xSLG        6744
# xwOBA       6744
# L-WAR          0
# NEXT_WAR    1207
# Length: 321, dtype: int64

# %%
complete_cols = list(batting.columns[null_count == 0])

# %%
complete_cols
# Out:
# ['IDfg',
#  'Season',
#  'Name',
#  'Team',
#  'Age',
#  'G',
#  'AB',
#  'PA',
#  'H',
#  '1B',
#  '2B',
#  '3B',
#  'HR',
#  'R',
#  'RBI',
#  'BB',
#  'IBB',
#  'SO',
#  'HBP',
#  'SF',
#  'SH',
#  'GDP',
#  'SB',
#  'CS',
#  'AVG',
#  'GB',
#  'FB',
#  'LD',
#  'IFFB',
#  'Pitches',
#  'Balls',
#  'Strikes',
#  'IFH',
#  'BU',
#  'BUH',
#  'BB%',
#  'K%',
#  'BB/K',
#  'OBP',
#  'SLG',
#  'OPS',
#  'ISO',
#  'BABIP',
#  'GB/FB',
#  'LD%',
#  'GB%',
#  'FB%',
#  'IFFB%',
#  'HR/FB',
#  'IFH%',
#  'BUH%',
#  'wOBA',
#  'wRAA',
#  'wRC',
#  'Bat',
#  'Rep',
#  'Pos',
#  'RAR',
#  'WAR',
#  'Dol',
#  'Spd',
#  'wRC+',
#  'WPA',
#  '-WPA',
#  '+WPA',
#  'RE24',
#  'REW',
#  'pLI',
#  'PH',
#  'WPA/LI',
#  'Clutch',
#  'FB% (Pitch)',
#  'FBv',
#  'SL%',
#  'SLv',
#  'CB%',
#  'CBv',
#  'CH%',
#  'CHv',
#  'wFB',
#  'wSL',
#  'wCB',
#  'wCH',
#  'wFB/C',
#  'wSL/C',
#  'wCB/C',
#  'wCH/C',
#  'O-Swing%',
#  'Z-Swing%',
#  'Swing%',
#  'O-Contact%',
#  'Z-Contact%',
#  'Contact%',
#  'Zone%',
#  'F-Strike%',
#  'SwStr%',
#  'BsR',
#  'Def',
#  'wSB',
#  'Age Rng',
#  'Off',
#  'Lg',
#  'Pull%',
#  'Cent%',
#  'Oppo%',
#  'Soft%',
#  'Med%',
#  'Hard%',
#  'TTO%',
#  'AVG+',
#  'BB%+',
#  'K%+',
#  'OBP+',
#  'SLG+',
#  'ISO+',
#  'BABIP+',
#  'LD+%',
#  'GB%+',
#  'FB%+',
#  'HR/FB%+',
#  'Pull%+',
#  'Cent%+',
#  'Oppo%+',
#  'Soft%+',
#  'Med%+',
#  'Hard%+',
#  'Events',
#  'CStr%',
#  'CSW%',
#  'L-WAR']

# %%
batting = batting[complete_cols + ["NEXT_WAR"]].copy()

# %%
batting
# Out:
#        IDfg  Season              Name Team  Age    G   AB   PA    H   1B  ...  \
# 5484      1    2006   Alfredo Amezaga  FLA   28  132  334  378   87   72  ...
# 4909      1    2007   Alfredo Amezaga  FLA   29  133  400  448  105   80  ...
# 5157      1    2008   Alfredo Amezaga  FLA   30  125  311  337   82   61  ...
# 2478      2    2004   Garret Anderson  ANA   32  112  442  475  133   98  ...
# 4069      2    2005   Garret Anderson  LAA   33  142  575  603  163  111  ...
# ...     ...     ...               ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1215  30116    2024      Seiya Suzuki  CHC   29   88  340  383   93   54  ...
# 5081  31347    2023         Zach Neto  LAA   22   84  289  329   65   39  ...
# 3004  31347    2024         Zach Neto  LAA   23  109  367  406   94   56  ...
# 2421  31837    2023  Masataka Yoshida  BOS   29  140  537  580  155  104  ...
# 3785  31837    2024  Masataka Yoshida  BOS   30   63  219  248   58   44  ...
#
#       Cent%+  Oppo%+  Soft%+  Med%+  Hard%+  Events  CStr%   CSW%  L-WAR  \
# 5484     107     113     143    109      63       0  0.188  0.256    1.1
# 4909     101     112     109    113      75       0  0.175  0.227    2.0
# 5157     101     101     123    111      64       0  0.178  0.244    1.2
# 2478     103      75      78    106      98       0  0.176  0.270    0.8
# 4069      78      83     100     97     106       0  0.150  0.258   -0.2
# ...      ...     ...     ...    ...     ...     ...    ...    ...    ...
# 1215     125      86      75     96     120     238  0.205  0.296    2.3
# 5081      82     103      81    108      97     216  0.161  0.290    1.1
# 3004      89      89      91    100     106     281  0.160  0.286    2.2
# 2421     102     117     123     99      91     458  0.212  0.285    0.6
# 3785     100     100     103     94     109     187  0.193  0.254    0.0
#
#       NEXT_WAR
# 5484       2.0
# 4909       1.2
# 5157       NaN
# 2478      -0.2
# 4069       0.1
# ...        ...
# 1215       NaN
# 5081       2.2
# 3004       NaN
# 2421       0.1
# 3785       NaN
#
# [6744 rows x 131 columns]

# %%
batting.dtypes
# Out:
# IDfg          int64
# Season        int64
# Name         object
# Team         object
# Age           int64
#              ...
# Events        int64
# CStr%       float64
# CSW%        float64
# L-WAR       float64
# NEXT_WAR    float64
# Length: 131, dtype: object

# %%
batting.dtypes[batting.dtypes == "object"]
# Out:
# Name       object
# Team       object
# Dol        object
# Age Rng    object
# dtype: object

# %%
batting["Dol"]
# Out:
# 5484      $5.5
# 4909     $11.2
# 5157      $7.2
# 2478      $3.4
# 4069    ($1.2)
#          ...
# 1215     $18.7
# 5081      $8.9
# 3004     $17.9
# 2421      $4.8
# 3785      $0.5
# Name: Dol, Length: 6744, dtype: object

# %%
del batting["Dol"]

# %%
batting["Age Rng"]
# Out:
# 5484    28 - 28
# 4909    29 - 29
# 5157    30 - 30
# 2478    32 - 32
# 4069    33 - 33
#          ...
# 1215    29 - 29
# 5081    22 - 22
# 3004    23 - 23
# 2421    29 - 29
# 3785    30 - 30
# Name: Age Rng, Length: 6744, dtype: object

# %%
del batting["Age Rng"]

# %%
batting["Team_Code"] =  batting["Team"].astype("category").cat.codes

# %%
batting_full = batting.copy()
batting = batting.dropna().copy()

# %%
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

rr = Ridge(alpha=1)

split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=20, direction="forward", cv=split, n_jobs=4)

# %%
removed_cols = ["NEXT_WAR", "Name", "Team", "IDfg", "Season"]
selected_cols = batting.columns[~batting.columns.isin(removed_cols)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# Out:
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.34615385 0.38461538 0.5        ... 0.34615385 0.11538462 0.38461538]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.73504274 0.74358974 0.56410256 ... 0.78632479 0.32478632 0.8034188 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.31294964 0.43165468 0.50719424 ... 0.63848921 0.23201439 0.67805755]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.30795848 0.42906574 0.47577855 ... 0.66262976 0.22318339 0.65743945]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.24568966 0.32327586 0.44396552 ... 0.50431034 0.15086207 0.5387931 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.27830189 0.31603774 0.4009434  ... 0.36320755 0.12264151 0.42924528]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.15254237 0.23728814 0.33898305 ... 0.52542373 0.28813559 0.55932203]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.13043478 0.39130435 0.04347826 ... 0.26086957 0.         0.13043478]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.0483871  0.03225806 0.22580645 ... 0.32258065 0.14516129 0.24193548]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.23021583 0.25899281 0.3381295  ... 0.4676259  0.20143885 0.43884892]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.08053691 0.15436242 0.45637584 ... 0.44966443 0.18120805 0.43624161]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.13100437 0.13973799 0.11353712 ... 0.24454148 0.07423581 0.13537118]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.03333333 0.         0.05       ... 0.025      0.         0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.17674419 0.20465116 0.31162791 ... 0.56744186 0.32093023 0.33953488]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.08823529 0.11764706 0.02941176 ... 0.05882353 0.47058824 0.20588235]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.0625 0.3125 0.1875 ... 0.4375 0.1875 0.125 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.29166667 0.16666667 0.         ... 0.         0.04166667 0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.15625 0.125   0.09375 ... 0.25    0.15625 0.625  ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.25641026 0.16666667 0.02564103 ... 0.07692308 0.06410256 0.1025641 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.5        0.29166667 0.04166667 ... 0.29166667 0.04166667 0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.30107527 0.34677419 0.34139785 ... 0.37634409 0.13978495 0.59408602]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.27862595 0.35496183 0.41984733 ... 0.44656489 0.27099237 0.40076336]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.22758621 0.3862069  0.49655172 ... 0.51034483 0.20689655 0.48965517]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.2        0.2        0.23076923 ... 0.16923077 0.10769231 0.15384615]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.31749049 0.41064639 0.4243346  ... 0.70494297 0.26463878 0.61026616]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.25358852 0.33971292 0.35964912 ... 0.60207337 0.2185008  0.47049442]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.34420772 0.43541944 0.44274301 ... 0.73169108 0.28095872 0.67576565]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.28070175 0.19298246 0.15789474 ... 0.33333333 0.0877193  0.38596491]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.23943662 0.25352113 0.         ... 0.         0.02816901 0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.10526316 0.21052632 0.         ... 0.         0.         0.        ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.19892473 0.24731183 0.33870968 ... 0.48924731 0.19892473 0.43548387]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.31896552 0.3362069  0.45258621 ... 0.5387931  0.37931034 0.46551724]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.31325301 0.31325301 0.02409639 ... 0.01204819 0.01204819 0.08433735]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.42553191 0.42553191 0.58510638 ... 0.61702128 0.37234043 0.64893617]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.20300752 0.17794486 0.13784461 ... 0.24561404 0.14035088 0.13283208]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.28787879 0.27272727 0.4040404  ... 0.41919192 0.42424242 0.21717172]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.34920635 0.33333333 0.38095238 ... 0.45238095 0.34920635 0.42857143]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.18382353 0.23529412 0.38970588 ... 0.49264706 0.30882353 0.42647059]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.08467742 0.14919355 0.27016129 ... 0.39919355 0.28629032 0.2983871 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.43333333 0.42222222 0.58888889 ... 0.63333333 0.37777778 0.54444444]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.60330579 0.54545455 0.43801653 ... 0.46280992 0.38016529 0.7107438 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.39310345 0.37241379 0.43448276 ... 0.42758621 0.54482759 0.27586207]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.08287293 0.04972376 0.27348066 ... 0.31767956 0.22099448 0.2679558 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.36206897 0.4137931  0.60344828 ... 0.45689655 0.60344828 0.38793103]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.53932584 0.47191011 0.49438202 ... 0.56179775 0.25842697 0.48314607]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.5037594  0.4962406  0.21804511 ... 0.34586466 0.42857143 0.53383459]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.66292135 0.47191011 0.29775281 ... 0.36516854 0.31460674 0.5505618 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.65217391 0.71014493 0.60869565 ... 0.42028986 0.63768116 0.50724638]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.19444444 0.27777778 0.4375     ... 0.55555556 0.43055556 0.38888889]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.         0.         0.         ... 0.65442404 0.360601   0.76460768]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/366146668.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[0.35294118 0.35294118 0.02941176 ... 0.17647059 0.44117647 0.14705882]' has dtype incompatible with int8, please explicitly cast to a compatible dtype first.
#   batting.loc[:, selected_cols] = scaler.fit_transform(batting[selected_cols])

# %%
batting.describe()
# Out:
#                IDfg       Season          Age            G           AB  \
# count   5537.000000  5537.000000  5537.000000  5537.000000  5537.000000
# mean    6978.167058  2013.163627     0.356143     0.649077     0.476371
# std     6137.835556     5.673558     0.145616     0.255848     0.241316
# min        1.000000  2004.000000     0.000000     0.000000     0.000000
# 25%     1677.000000  2008.000000     0.230769     0.470085     0.275180
# 50%     5222.000000  2013.000000     0.346154     0.709402     0.498201
# 75%    11265.000000  2018.000000     0.461538     0.871795     0.685252
# max    31837.000000  2023.000000     1.000000     1.000000     1.000000
#
#                 PA            H           1B           2B           3B  ...  \
# count  5537.000000  5537.000000  5537.000000  5537.000000  5537.000000  ...
# mean      0.477838     0.360908     0.285923     0.388830     0.100172  ...
# std       0.260889     0.181194     0.137847     0.167153     0.104292  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.256055     0.211207     0.174528     0.254237     0.043478  ...
# 50%       0.503460     0.362069     0.278302     0.372881     0.086957  ...
# 75%       0.705882     0.504310     0.386792     0.508475     0.130435  ...
# max       1.000000     1.000000     1.000000     1.000000     1.000000  ...
#
#             Oppo%+       Soft%+        Med%+       Hard%+       Events  \
# count  5537.000000  5537.000000  5537.000000  5537.000000  5537.000000
# mean      0.402198     0.411122     0.509725     0.468299     0.227437
# std       0.130916     0.121268     0.132891     0.133415     0.293529
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.315789     0.331461     0.420290     0.375000     0.000000
# 50%       0.398496     0.404494     0.507246     0.472222     0.000000
# 75%       0.488722     0.488764     0.594203     0.555556     0.477462
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#              CStr%         CSW%        L-WAR     NEXT_WAR    Team_Code
# count  5537.000000  5537.000000  5537.000000  5537.000000  5537.000000
# mean      0.497911     0.551830     0.339416     1.758154     0.479039
# std       0.136366     0.121706     0.127327     1.942325     0.305139
# min       0.000000     0.000000     0.000000    -3.100000     0.000000
# 25%       0.408511     0.471366     0.246667     0.400000     0.205882
# 50%       0.493617     0.550661     0.320000     1.400000     0.470588
# 75%       0.591489     0.634361     0.406667     2.800000     0.735294
# max       1.000000     1.000000     1.000000    11.200000     1.000000
#
# [8 rows x 128 columns]

# %%
sfs.fit(batting[selected_cols], batting["NEXT_WAR"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=Ridge(alpha=1), n_features_to_select=20,
#                           n_jobs=4)

# %%
predictors = list(selected_cols[sfs.get_support()])

# %%
def backtest(data, model, predictors, start=5, step=1):
    all_predictions = []

    years = sorted(data["Season"].unique())

    for i in range(start, len(years), step):
        current_year = years[i]

        train = data[data["Season"] < current_year]
        test = data[data["Season"] == current_year]

        model.fit(train[predictors], train["NEXT_WAR"])

        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["NEXT_WAR"], preds], axis=1)
        combined.columns = ["Actual", "Prediction"]

        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(batting, rr, predictors)

# %%
predictions
# Out:
#       Actual  Prediction
# 5446     1.6    0.353958
# 2674     0.3    1.349977
# 4624    -1.1    0.389569
# 6098     0.2    0.605145
# 2312     0.4    1.009840
# ...      ...         ...
# 4541     1.4    1.936450
# 1373     0.6    2.569413
# 1310     2.3    2.386686
# 5081     2.2    2.247648
# 2421     0.1    1.018143
#
# [4091 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(predictions["Actual"], predictions["Prediction"])
# Out:
# 2.5929308447187367

# %%
# Rule of Thumb is to get the mean_squared_error lower than the std dev value to indicate our model is better than just random guesses
batting["NEXT_WAR"].describe()
# Out:
# count    5537.000000
# mean        1.758154
# std         1.942325
# min        -3.100000
# 25%         0.400000
# 50%         1.400000
# 75%         2.800000
# max        11.200000
# Name: NEXT_WAR, dtype: float64

# %%
2.5929308447187367 ** .5
# Out:
# 1.6102580056372136

# %%
def player_history(df):
    df = df.sort_values("Season")

    df["player_season"] = range(0, df.shape[0])
    df["war_corr"] = list(df[["player_season", "WAR"]].expanding().corr().loc[(slice(None), "player_season"), "WAR"])
    df["war_corr"].fillna(1, inplace=True)

    
    df["war_diff"] = df["WAR"] / df["WAR"].shift(1)
    df["war_diff"].fillna(1, inplace=True)
    
    df["war_diff"][df["war_diff"] == np.inf] = 1

    return df

batting = batting.groupby("IDfg", group_keys=False).apply(player_history)
# Out:
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_corr"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["war_diff"].fillna(1, inplace=True)
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["war_diff"][df["war_diff"] == np.inf] = 1
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/1089691491.py:16: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   batting = batting.groupby("IDfg", group_keys=False).apply(player_history)

# %%
def group_averages(df):
    return df["WAR"] / df["WAR"].mean()

# %%
batting["war_season"] = batting.groupby("Season", group_keys=False).apply(group_averages)
# Out:
# /var/folders/wn/kjhkcp0x4c94gmv1184_v4t00000gn/T/ipykernel_32257/4191086496.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   batting["war_season"] = batting.groupby("Season", group_keys=False).apply(group_averages)

# %%
new_predictors = predictors + ["player_season", "war_corr", "war_season", "war_diff"]

# %%
predictions = backtest(batting, rr, new_predictors)

# %%
mean_squared_error(predictions["Actual"], predictions["Prediction"])
# Out:
# 2.5504135719796452

# %%
pd.Series(rr.coef_, index=new_predictors).sort_values()
# Out:
# Age             -2.932391
# G               -1.783551
# ISO             -1.718438
# WAR             -1.610597
# BABIP           -1.507009
# O-Swing%        -1.492796
# BU              -1.136711
# Soft%+          -0.775183
# LD+%            -0.490703
# BABIP+          -0.433974
# war_diff        -0.343573
# war_corr        -0.150458
# player_season    0.012615
# PH               0.335667
# GDP              0.460070
# CS               0.527972
# Oppo%            0.629570
# O-Contact%       0.762220
# Swing%           0.934272
# Spd              1.137245
# Strikes          1.558588
# IBB              1.931718
# Hard%+           2.308678
# war_season       3.218566
# dtype: float64

# %%
diff = predictions["Actual"] - predictions["Prediction"]

# %%
merged = predictions.merge(batting, left_index=True, right_index=True)

# %%
merged["diff"] = (predictions["Actual"] - predictions["Prediction"]).abs()

# %%
merged[["IDfg", "Season", "Name", "WAR", "NEXT_WAR", "diff"]].sort_values(["diff"])
# Out:
#        IDfg  Season             Name       WAR  NEXT_WAR       diff
# 7047  15082    2017       Adam Engel  0.220000       1.1   0.000077
# 5748   6609    2013    Freddy Galvis  0.220000       1.6   0.000485
# 2264  14566    2020    Franmil Reyes  0.260000       1.7   0.000899
# 2686   3531    2015  Troy Tulowitzki  0.366667       2.3   0.000996
# 1835   5361    2011  Freddie Freeman  0.246667       1.7   0.001939
# ...     ...     ...              ...       ...       ...        ...
# 3705   1875    2009    Josh Hamilton  0.293333       8.4   6.379830
# 798    9166    2010     Buster Posey  0.466667       9.8   6.386642
# 409   15640    2021      Aaron Judge  0.573333      11.2   7.444170
# 2427  11579    2014     Bryce Harper  0.313333       9.3   7.500714
# 1927    319    2012        Adam Dunn  0.346667       0.4  12.986821
#
# [4091 rows x 6 columns]
